# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Read Raw Data and Combine No Service to No

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df = df.drop(['customerID','TotalCharges'],axis=1)

# %%
df.loc[df['MultipleLines']=='No phone service','MultipleLines'] = 'No'
df.loc[df['OnlineSecurity']=='No internet service','OnlineSecurity'] = 'No'
df.loc[df['OnlineBackup']=='No internet service','OnlineBackup'] = 'No'
df.loc[df['DeviceProtection']=='No internet service','DeviceProtection'] = 'No'
df.loc[df['TechSupport']=='No internet service','TechSupport'] = 'No'
df.loc[df['StreamingTV']=='No internet service','StreamingTV'] = 'No'
df.loc[df['StreamingMovies']=='No internet service','StreamingMovies'] = 'No'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 1.0+ MB

# %%
len(df)
# Out:
# 7043

# %% [markdown]
# ### Step 2: Download Tweets with keywords "T-Mobile" and "Verizon"

# %%
import tweepy
from textblob import TextBlob
import preprocessor as p
import statistics
from typing import List

# %% [markdown]
# #### Import consumer_key and consumer_secret obtained from Twitter Developer Account

# %%
consumer_key = 'C2yPbBxFC14dsNuekxhc5segd'
consumer_secret = 'szQgWnWrkMTgWKt2PyCkZgdrpvhatqMxPu3hidHk4NNExR1IRV'

# %%
auth = tweepy.AppAuthHandler(consumer_key,consumer_secret)
api = tweepy.API(auth)

# %% [markdown]
# #### Create function to download tweets from Twitter with keyword

# %%
def get_tweets(keyword: str) -> List[str]:
    
    all_tweets = []
    for tweet in tweepy.Cursor(api.search, q=keyword, tweet_mode='extended',lang='en').items(4000):
        all_tweets.append(tweet.full_text)
    
    return all_tweets

# %% [markdown]
# #### Create function to do initial basic cleaning for tweets downloaded

# %%
def clean_tweets(all_tweets: List[str]) -> List[str]:
    
    tweets_clean = []
    for tweet in all_tweets:
        tweets_clean.append(p.clean(tweet))
    
    return tweets_clean

# %% [markdown]
# #### Download 4000 tweets with keyword 'T-Mobile' and another 4000 tweets with keyword 'Verizon'

# %%
Tweet1 = clean_tweets(get_tweets('T-Mobile'))

# %%
Tweet1
# Out:
# ["Making sure you get the most out of T-Mobile Tuesdays is key and we'd love to help! Please send us a DM, we'll meet you there! ^RyanMitchener",
#  'The Note was just launched. I\'m so glad that I actually found you advertisement. I had no idea that these phone actually exist. Q" Where can I buy? And can a national carrier like T-MOBILE allow service for it? Or where must I go for service?" I have Samsung Note now.',
#  ': I get penalized for being broke with my T-Mobile phone bill. They disconnect you and make you pay',
#  'Just changed my Sprint SIM card for a T-mobile one and I have less bars at home. Devil in a new dress',
#  ': Oh I hear you! Between my wife and me we are k cant afford a second vehicle. Paying $246 a mon',
#  ': I get penalized for being broke with my T-Mobile phone bill. They disconnect you and make you pay',
#  "I was with T-Mobile since the Voice Stream days. Never had a problem, loved it. Only reason I don't have it now because I live in New Zealand. You need to roll it out here.",
#  'what the fuck, i guess i have t-mobile now. thats GAHDJAKKSKS',
#  'Just switched my Sprint SIM card out for a T-Mobile one and I have less bars at home. Devil in a new dress',
#  'Just replaced my Pixel with a ! (Yes, I stay a generation behind.) Are you happy with the AT&amp;T service? I initially moved to T-mobile because I was getting lousy coverage/service from AT&amp;T, but that was years ago.',
#  'My parents, watching the Billie Eilish documentary: Oh my god I cant believe her parents would let her date a year old when she was thats crazyMy parents: *tried to set y/o me up with a y/o that helped them at t-mobile*',
#  'Damn. Sprint sent me a new T-Mobile SIM card for my phone. Now my shit says T-Mobile',
#  't-mobile is the worst phone service omg',
#  'My baby told me go buy her AirPods today I walked right out of apple &amp; forgot ... Im not going back either. Lemme go to T-Mobile',
#  'Make sure you hit up T-Mobile Tuesdays so you can aim for that instead of lmao',
#  'Still faster then t-mobile',
#  ': Listen to the most recent episode of my podcast: Facebook in $650M Privacy Lawsuit Settlement, T-Mobile Users Affec',
#  'Absolutely. Would outfit T-Mobile Park like a game of Minecraft. Little surprises/secrets to be discovered all over the park, for adults and kids alike. Next question?',
#  'Samsung Galaxy S9+ Plus SM-G965U GB Factory Unlocked Smartphone AT&amp;T T-MOBILE -',
#  'idk how to answer that. it connects to T-Mobiles G network &amp; bridges the connection over a th-gen WiFi network. I havent encountered the acronym WWAN in many years &amp; never truly learned how it is different than WLAN/WiFi &amp; a commercial cellular network like T-Mobiles',
#  "I'm on t-mobile and I like it, but is the pitch that it's t-mobile but cheaper? That's my takeaway.",
#  'Buy one voice Line T-Mobile , &amp; get the second free for life! Come see me !',
#  'T-mobile. I broke my screen during the first mins of game',
#  'Our SATURDAY SUPPORTER SHOUT OUT this week is Metro by T-Mobile We thank you for all of the ways you have helped us provide for Lancaster residents as well as keeping our building looking nice!',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there',
#  ': Who is looking to save some ?Come and save switching to T-Mobile and get a smart phone on us ! We the famous R',
#  "extremely stoked that I'm paying for this internet thank you T-Mobile thank you",
#  'Watch I be at T-Mobile eva',
#  'really not feeling giving t-mobile any money this month please feel free to contact me thru vibes this coming month',
#  'Why is this T-Mobile ad about black history turned around to talk about work place and company culture?',
#  'We appreciate you reaching out to us and are here to help with any and all things T-Mobile! Please meet us in DM if you need any assistance! ^RyanMitchener',
#  "My sister just got T-Mobile's wireless internet thing set up at her house. She's getting around Mbps down for the same price that we're paying for Mbps...So, I go on T-Mobile's site to do the availability check. Answer is no...my sister's house is a /4 mile away...fml",
#  'This week T-Mobile Tuesday had a $2 card for Dunkin Donuts so I got a hazelnut latte from there yesterday. I usually frequent Starbucks tho.',
#  'aaron is such a t-mobile employee type name',
#  'dead ass done with T-Mobile.',
#  "I guess the only way to handle this situation is going to be through a lawyer and a lawsuit. I could have been an easy open/closed settlement. Let's see how fast they contact me now.Anyone else have this happen to them with T-mobile ? Identity theft ? Class Action Lawsuit ?",
#  'Is this the T-mobile way? As a customer, I expect SECURITY on their behalf. Their employee ruined my Christmas this past Dec. Since all this took place on Dec. st. This needs some public attention. I waited almost months for them to get back to me and there have been no',
#  'had my phones SIM card swapped by a T-Mobile employee in New Brunswick N.J back in December. Since then I have gotten nothing but false promises of call backs and compensation. Been a long time customer, but the fact that their employee used their position to',
#  'to -Mobile in United States: speed, performance, outages and user reviews -Mobilevia',
#  "Hey I've heard there is a high demand for the T-Mobile REVVL . Maybe you could consider taking a look it it?",
#  'I hate T-Mobile so bad wow',
#  'I also get MLB dot TV for free every year from T-Mobile so thats awesome too',
#  ': Who is looking to save some ?Come and save switching to T-Mobile and get a smart phone on us ! We the famous R',
#  ': Who is looking to save some ?Come and save switching to T-Mobile and get a smart phone on us ! We the famous R',
#  'Go to T-Mobile and get a new SIM card. Theyre doing free SIM card upgrades for sprint customers since theyre switching the networks',
#  ': Does anyone on t-mobile want an Android phone? I have an LG G6 which t-mobile just flat out refuses to unlock. Even the owner',
#  'T-Mobiles service is so garbage.',
#  'I love their spicy chicken sandwich and fries! T-Mobile Tuesday has a free chicken sandwich offer this upcoming Tuesday and I cannot wait. Popeyes &gt; Chick Fil-A, imo. Chick Fil-A sandwiches are too plain for my taste.',
#  ': T-Mobile sets sights on enterprise markets ://',
#  "Gotta love losing T-Mobile network connectivity in a G area, totally dropped coverage while never leaving a G area, and not getting any coverage back until I restart my phone when I'm back at home. I'd be rich if I had a dollar for how often this happens.",
#  "Owler Reports - T-Mobile: T-Mobile saw Verizon telling people to turn off G and thought 'why stop there'",
#  'T-Mobile sets sights on enterprise markets ://',
#  "list of companies that don't want Black Americans to vote AT&amp;T Verizon WalgreensAetna/CVS/Caremark T-Mobile AflacLyft WalmartSunTrust UnitedHealthPublixGeneral MotorsHome DepotUPSCoca-ColaSouthern CompanyComcast Delta Air Lines",
#  'I have seen an increase to about or a day for the last month! I just got a new SIM card from T-Mobile and the spam blocker has captured about a day for the last week. But three or four have still come through.',
#  ": Palm Springs Downtown SpeedTestin' | Verizon vs T-Mobile vs AT&amp;T | impressive TMO performance.",
#  ": WHen I say T-Mobile n71 performs quite well in rural areas (or just areas that don't have a ton of congestion), this is what I",
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  "Here's a look at the current situation at Metro, a T-Mobile prepaid brand. Learn about its rate plans, phone selection, and limited time deals.",
#  "WHen I say T-Mobile n71 performs quite well in rural areas (or just areas that don't have a ton of congestion), this is what I'm talking about, with + Mbps down and well over Mbps up. It takes n41 to get those speeds in denser areas.",
#  'FIRST SNKRS PASS HIT EVERDevice : iPhone XGroups: Proxy: T-Mobile Lte data',
#  "T'is hard building (Numero Uno) - so easy to lose designation. Suggest: appoint regional social media ambassadors (SMA) charged with maintaining T-Mobile visibility on the interwebs... Improve spreadsheets explaining availability areas for roll-outs.",
#  ': Listen to the most recent episode of my podcast: Facebook in $650M Privacy Lawsuit Settlement, T-Mobile Users Affec',
#  'T-Mobile free wifi ftw',
#  ': Apple Watch Series Buy one Get one $ off at T-Mobile! Dont miss out on these amazing offers!',
#  ': Apple Watch Series Buy one Get one $ off at T-Mobile! Dont miss out on these amazing offers!',
#  'Were here for ONE MORE HOUR! And weve still got some $25 Visa Gift Cards to giveaway! Just show up before they run out! Were at Metro by T-Mobile off Highway in Austin until ! We will even load a case of in your car!',
#  'Apple Watch Series Buy one Get one $ off at T-Mobile! Dont miss out on these amazing offers!',
#  ': T-Mobile wants your employer to give you home-office wireless broadband',
#  'Listen to the most recent episode of my podcast: Facebook in $650M Privacy Lawsuit Settlement, T-Mobile Users Affected By SIM Swap Fraud &amp; How To Prevent A SIM Swap Attack',
#  ': Who is looking to save some ?Come and save switching to T-Mobile and get a smart phone on us ! We the famous R',
#  'Mfs at T-Mobile cant do they job I see',
#  "Palm Springs Downtown SpeedTestin' | Verizon vs T-Mobile vs AT&amp;T | impressive TMO performance.",
#  'Walmart, SunTrust/Truist, UnitedHealth, Publix, General Motors, Home Depot, UPS, Coca-Cola, Southern Company, Comcast, Delta Air Lines, Pfizer, AllState, Anthem/BCBS Georgia, Anheuser-Busch, Verizon, Walgreens, T-Mobile, and Aflac.',
#  "Even at the top of the mountain T-mobile has coverage to post!! And was able to share hotspot with some folks at the lounge which was nice since AT&amp;T wasn't working for them.",
#  'Hello Cissy! We would love to keep you part of the New T-Mobile family. Making sure things are okay with your connection is important to stay connected to everyone. Please shoot us a DM to further assist you. ^ElizabethV',
#  'Haha, laughed my a$$ off... Look at T-Mobile. Im a customer, now part and they have some spectacular plans. My connectivity has been superior to previous services with at&amp;t and Verizon. Plus they just bought me $5 in Bitcoin through their T-Mobile Tuesdays',
#  "is so ridiculous! I dropped apple products a long time ago but unfortunately had to buy some ipads for my business. One got locked out and will not unlock it unless I provide them a reciept from over years ago. They won't even accept my T-Mobile monthly data bill",
#  'fuck sprint fuck t-mobile fuck at&amp;t fuck verizon FUCK U ALL',
#  'I am proponent of T-Mobile for most of the past years. % backer until recently. At T-store Nov20 excited for TVision - three weeks later hung up my hubs and went to youtubeTV. ABQ &amp; MFE could not get mine to work...',
#  ': My ears are bleeding theyre playing Drake at this T-Mobile',
#  'Went to t-mobile to upgrade. Girl who helped me was so nice. When all was said and done I asked her how much. Do you know what she said? She said "I need about tree fiddy." That\'s when I realized this t-mobile employee was stories tall and was a creature from the mezazoic era.',
#  'T-Mobile and these spam calls',
#  "The Culture has to Readjust its Interpretation of Success - it would rather be surprising how many More of these Instances The General public has been Misled and Lied too. that's why its always important to Stay in Study Mode. The T-Mobile Spot flew over Multiple heads.",
#  'T-Mobile dry fit shirts',
#  ': Does anyone on t-mobile want an Android phone? I have an LG G6 which t-mobile just flat out refuses to unlock. Even the owner',
#  'T-mobile needs to really get it together !!!',
#  'My ears are bleeding theyre playing Drake at this T-Mobile',
#  'Sr Software Engineer (Javascript, Node.js) needed in at T-Mobile Careers. Apply now!',
#  'Sony Xperia Z1S C6916 GB G LTE Black T-Mobile WaterProof Smartphone -',
#  ': FCBA panel discussion Tues. March at pm ET: Fostering Equity, Inclusion, and Equality in the Workplace. Speakers Kimberley',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  "It's not something that like. Comes up casually in conversation with others. I can't peddle it like I did t-mobile u feel me?",
#  ': Your Exclusive Technology News:Nokia with Android One (32GB, GB) " HD+ Display, MP Dual Camera, GSM Unlock',
#  'Finally have a phone number Im wit T-Mobile now tho I swear my bill better not change',
#  ': I get penalized for being broke with my T-Mobile phone bill. They disconnect you and make you pay',
#  ': Oh I hear you! Between my wife and me we are k cant afford a second vehicle. Paying $246 a mon',
#  't-mobile pissing me off',
#  'Who is looking to save some ?Come and save switching to T-Mobile and get a smart phone on us ! We the famous Route Sids dinner S Choctaw Ave, El Reno, OK . Until pm',
#  'good looking out Dan on that T-mobile info',
#  'Ordered moms and Nisis birthday gift. March kills me! I just ordered the iPhone for myself and switched to AT&amp;T. T-Mobile was charging me out the ass.',
#  "Thank you for being the leader of unlimited, if it wasn't for T-mobile we would still be watching our data limits.",
#  'T-Mobile Home Internet',
#  'Happy th! Always a great leader at t-mobile!',
#  'When ya look good, ya feel good. AT&amp;T me vs T-Mobile me.',
#  ': Does anyone on t-mobile want an Android phone? I have an LG G6 which t-mobile just flat out refuses to unlock. Even the owner',
#  'Sprint/T-Mobile.',
#  "So I'm just letting you know I'm getting ready to file arbitration against T-Mobile if they don't make it right",
#  "yes this is Christopher Hunter I used to be a customer of T-Mobile well this is twice I was using T-Mobile and for some reason y'all had yeah haircut my service after I I had talked to one of your assistance so they decide to cut my service not once but twice",
#  'T-Mobile wants your employer to give you home-office wireless broadband',
#  'T-Mobile customers get it free March th',
#  'T-Mobile is a consumer favorite. Now it&amp;apos trying to break into the business world T-Mobile has been popular with consumers, but an underdog when it comes to serving businesses. The "Uncarrier" wants to change that with the rollout of G.',
#  'I would of got me a cheap plan frm T-Mobile and whatever free phone they giving lol... a Car that take me frm A to B. No this fool wants a new . If he could, hed get a ... since his ass dont pay child support. Piece of shit.',
#  ': Does anyone on t-mobile want an Android phone? I have an LG G6 which t-mobile just flat out refuses to unlock. Even the owner',
#  'Call them and see if they have a prepaid service. If they do you can just carry your phone over since its already for T-Mobile',
#  'If T-Mobile wasnt paying for my netflix I literally would not have one. Lmaoo nexflix went from to who cares we on HBO Max',
#  'T-Mobile Careers is looking for a Mobile Associate - Retail Sales in , apply now!',
#  'Me: *runs to T-Mobile store real quick to look at accessories*T-Mob: "sir we have to sign you in."Me, jokingly: "Sign in just to buy a quick accessory? What\'s that like minutes?"T-Mob: "An hour, Sir."Me:',
#  "Does anyone on t-mobile want an Android phone? I have an LG G6 which t-mobile just flat out refuses to unlock. Even the owner of the phone store that sold it to me can't unlock it. If I return it, he'll swap out the logic board and lose money. Feel free to share.",
#  ': Did T-Mobile merge with Claro like whats going on?',
#  'we are bringing the Un-carrier mission to enterprise businesses. Mike Katz, EVP of T-Mobile for Business, shares how T-Mobile WFX allows employees to work from virtually anywhere, changing the industry!',
#  'Lmao. My Verizon is what got me a PS5 when T-Mobile wouldnt even refresh the page. Fucken trash',
#  'The strategy is dont use T-Mobile ever . Smfh',
#  "You guys stole $160+ from my bank account for a bogus charge to my closed T-Mobile Internet account. Get in touch and let's resolve this matter.",
#  "You can get two lines with unlimited data at T-Mobile for $120, even less if you are a vet or over . As for your bad credit, it's not up to an employer to pay you more because you made bad purchase decisions in the past.",
#  '- (Amazon Bestsellers Top Unlocked Cell Phones Of the Week Upto % Discount Top Brand Deals - Apple iPhone XS Max, GB, Space Gray - For T-Mobile ...) discount offer from Wireless &amp;amp; Phones deal. Latest Offer for today. + ...',
#  'Join the T-mobile team! Our latest job opening Electricalengineerjobs Sacramento, CA',
#  "I've been using Metro PCS (whatever it's become now) for phone lines for a couple of years. It's due to renew today. Should I switch to some other provider? Not T-Mobile, though.",
#  "I generally don't have many inbound spam calls with the spam filters from T-Mobile, (other than the occasional 'you don't have a Google Listing') however, my number sure does get spoofed a lot.",
#  '"Among the many high-level jobs at mobile network operators, few are more consequential than those tasked with converting a network into a money-making machine." Read more in this interview with T-Mobile\'s John Saw.',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'T-Mobile US "patient and fearless men of science". In so doing, he',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'I cant even switch companies here bc T-Mobile is the only one cheap enough to afford at all. So its like... a vicious cycle that perpetuates my flavor of misery.',
#  'SAMSUNG GALAXY S10E SM-G970U GB BLUE UNLOCK VERIZON AT&amp;T T-MOBILE FEDEX DAY -',
#  'Oh I hear you! Between my wife and me we are k cant afford a second vehicle. Paying $246 a month on T-Mobile right now. Gotta make decisions on whats more important or we will be in trouble on bills. Its insane Im in Arizona. On paper we do ok. But we dont in reality!!',
#  'Weekly News Indoctrination-March th -Dr Seuss,T-Mobile,Biden same a... via',
#  'T-Mobile just hung up in my face I hate them',
#  ': T-Mobile wants your employer to give you home-office wireless broadband',
#  'I get penalized for being broke with my T-Mobile phone bill. They disconnect you and make you pay a lot for the reconnect fee. In any case, this is only ONE example of MANY I could list.',
#  'We would love to have you join T-Mobile and be able to take advantage of every UnCarrier benefit! Check out some info here: and DM us with any questions you have. ^JennaLundh',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  ': $SRMXHas a T-mobile contract for "smart IOT Streetlights" and "edge security camera systems" for smart cities/ build',
#  'On God T-Mobile Better Give Me My Fuckin Money Back',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'Installed T-mobile G Home internet today; Cancelled my Comcast Xfinity contract',
#  ': Are you a Mobile Event Expert - Lubbock, TX in ? T-Mobile Careers is waiting for you!',
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  'The Chicago White Soxs played the Toronto Blue Jays on May rd at T-Mobile Park. The final score was -13.',
#  'fuck it lets all quit n be T-Mobile clerks',
#  ': BITCH fuck yo dad t-mobile got the galaxy s3 two for $200!! RT : Everybody pray for my dad...please',
#  ': Why Verizon, AT&amp;T and T-Mobile just spent $80 billion in an auction, and what it will mean for G:',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  ': I love billion times more than T... (spelled backwards is alseT)In the future, we all know that the brand B... (ex:',
#  "We want to ensure that you are having the best experience with T-Mobile Home Internet Steven and that you're assisted efficiently. Send us a DM, we're here for you and a message away to help. ^MarkMcLaughlin",
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  'Ive been having issues with my T-Mobile home internet lately. To the point that I can only use one thing at a time, wether its steaming, doing stuff on my phone, or using my laptop. Tried to call many times and its always a + hr wait. Help!',
#  'They are opening up the website today afternoon to apply for Yuba area for T-Mobile!! Apply at and hit me up once you do!',
#  'hello T-Mobile I have never had an account with you and I am currently on a government phone I would love a new phone I need a new phone really bad like maybe one with G is there anything like that that I can get into just by accepting a plan so free phone in other word',
#  'It is a pleasure building a new STR program with he is amazing to work with. Thank for sharing your + years of T-Mobile wisdom with all us.',
#  'T-Mobile had me fucked up this morning',
#  "Nice. The carrier that doesn't exist in my area yet. My carriers are US Cellular (for my phone) and Sprint (for my iPad). I guess the iPad will get T-Mobile at some point though.",
#  'One thing about T-Mobile....they make sure they get diverse women in leadership. I encourage anyone career hunting to check out T-Mobile. A lot of movement and things happening in the company!!!',
#  'It is as though the referees are on a red card bonus. That idiot has completely ignored his T-MOBILE, who has clearly said there is no foul play and sent off a player based on the facts. The facts are IT IS NOTHING OTHER THAN A RUGBY INCIDENT YOU ABSOLUTELY USELESS TWAT!!!!!',
#  'T-Mobile service so fucking GARBAGE',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'in our modern tech world when you call a company with a problem many companies use this term our system wont allow as if computers are in charge . T-Mobile has the most human tone to their customer service.',
#  ': Call me crazy, but I JUST said to Jack that I may drop Verizon and go back to T-Mobile and like seconds later there is',
#  "It's always T-Mobile's goal to keep our customers happy and connected! We'd love to look into this further for you. We've got your back, my friend! Please send us a DM and we can check this out right away! ^JocelynArteaga",
#  "seriously, how are y'all worse at spam detection than T-Mobile? Multiple spam calls per day, I'm seriously about to rage quit the service after only a month. Please tell me I'm just missing a setting somewhere.",
#  'lines with T-Mobile. business crashed during a hurricane. No income. not able to keep my pay plan on an already big past due. were shut down. called them up with zero $ .they turned back on said stay in touch. months later paid in full',
#  ': Sprint and T-Mobile combined to make the worst data carrier possible',
#  'Dont test me mr T-Mobile',
#  'Its a good thing only around k people go to a game. Thats less than Spri... T-Mobile center. Keep in mind that very few stadiums have great downtown parking, I for one think it would work great. Dennys, Taco Bell and subway across the street aint cuttin it.',
#  'T-Mobile Sets Disruptive Sights On The G Cellular Business Market via',
#  'idc about your zodiac . who was in your T-Mobile fast',
#  'T-Mobile is fuckin ass now they really fucked themselves over tryna merge w sprint',
#  'Jacob, we would love to have you here at T-Mobile and we have some awesome benefits to offer. There has never been a better time to switch, we want to help you experience our awesome G network. Send us a DM so we can explore your options on making the move. ^JeromyBingham',
#  "I'm a Sprint customer and I've had the same cell number since . No joke. They have been very good to me over the years. However, I did not care for the merger with T-Mobile. This nonsense is what will push me to switch to a different provider after almost years. SMH",
#  'Idk how you get grandfathered in this long but we riding it til the wheels fall off. Maybe T-Mobile will find a way to kick us off it cause sprint caint and couldnt.',
#  'Oh yes. They advertise this in the T-Mobile Tuesdays app that I visit religiously to get my weekly -cent gas discount.',
#  'Sign a contract with me, and join T-Mobile.',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  'S/o to T-mobile!!',
#  'T-Mobile Sets Disruptive Sights On The G Cellular Business Market',
#  'TIL that telco carrier T-Mobile is also a bank',
#  'Why do all you jax folks have t-mobile',
#  ': SHOUT OUT to these ROCKSTARS for their Annual WC achievement! THANK YOU for d',
#  ': and Sprint have merged, which means youre getting expanded network coverage and other free perks with T-Mobile Tuesda',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  'T-Mobile, the second largest mobile network operator in the United States, told users to turn off the g function of g smart phones because g smart phones consume too much power.',
#  'Ook veel eigennamen:A-mode, B post, C-Mine, D-Cure, F-Secure, G-Star, M-Design, P-Magazine, Q-Party, S-Works, T-Mobile, ...',
#  'T-Mobile woke up and picked violence today. Im not paying on a phone that I already paid off',
#  'T-Mobile, Like Verizon, Also Tells Users to Turn Off G to Save on Battery Life',
#  'Partnerships with Bosch, T-Mobile and Festo. Mainnet v2.0 releasing this month. $Fet',
#  'WTF do T-Mobile have my insurance claim under review if I lost it I paid the deposit send me my f****** phone',
#  'How I just paid $ when I meant to pay my $ T-Mobile bill IS BEYOND ME',
#  'I literally did the same! Ever since T-Mobile did the merge service is trash.',
#  'Samsung Galaxy S9+ - T-mobile - Smartphone - Black - WORKS GREAT!!! -',
#  'Drake look like every T-Mobile Dominican nigga',
#  ': Microsoft Azure and T-mobile are directly mentioned',
#  'thank you for a great company. So I have a suggestion I know youre a great CEO and Im just a little man but I was thinking maybe T-Mobile creates a bill forgiveness initiative. Depending on the circumstances of which a customer has the -contd',
#  ': T-Mobile Promised Major Job Growth Post Sprint Merger. SEC Filings Show The Exact Opposite Happened',
#  'Samsung Galaxy S10 Plus G975U GB Factory Unlocked Verizon AT&amp;T T-Mobile Blue -',
#  'ugh I want to get my own phone plan thats cheap but I think I have to buy another phone so that I can have more options. I tried to find something on T-Mobile and at &amp;t but their both expensive for one phone line.',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max',
#  ': T-Mobile taxing on my bill idek what I be paying for',
#  '"Among the many high-level jobs at mobile network operators, few are more consequential than those tasked with converting a network into a money-making machine." Read more in this interview with T-Mobile\'s John Saw.',
#  'Microsoft Azure and T-mobile are directly mentioned',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  'T-Mobile taxing on my bill idek what I be paying for',
#  'just was told by T-Mobile that they dont care. Well charge you whatever we want. We can screw you however we want. Looking for another carrier',
#  ': Vaccines: Aetna/CVS/CaremarkPfizerWalgreensWalmartUnitedHealthAnthem/BCBS Georgia.Also AT&amp;T, SunTrust/Truist, Publ',
#  'Vaccines: Aetna/CVS/CaremarkPfizerWalgreensWalmartUnitedHealthAnthem/BCBS Georgia.Also AT&amp;T, SunTrust/Truist, Publix, GM, Home Depot, UPS, Coca-Cola, Southern Company, Comcast, Delta Air Lines, AllState, Anheuser-Busch, Verizon, T-Mobile,Aflac',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  "can I have somebody from your executive customer care team call me today about my account please I used to talk to John's people but you're now in charge so if I could speak to somebody today that would be great thank you love T-Mobile",
#  'Promotions at T-Mobile at the C level - Callie Field to Chief Customer Experience Officer- Marcus East to Chief Digital Officer- Brian King to Chief Information Officer',
#  'I need to head to T-Mobile todayyyyy, I need a new screen protector.',
#  ': was the craziest year in most of our lives. We had AMAZING employees step up across our T-Mobile family and support ou',
#  'T-MOBILE Breach Affect Over Million Clients',
#  'ZTE ZMAX Pro Z981 - GB G LTE Smartphone -Black (T-Mobile) UNLOCKED Pre Owned -',
#  'Dell Latitude Touchscreen Laptop FHD Display, Intel Core I5-8350U Processor GB DDR4 Ram, gb SSD, G LTE Sim Enabled (AT&amp;T, T-Mobile), WI-FI, Bluetooth. SD Card Windows Pro(Renewed)',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'The Los Angeles Angels played the Miami Marlins on July st at T-Mobile Park. The final score was -1.',
#  'T-Mobile service been tripping this morning',
#  'My bm know how I make payments lol... Thats why she never put me on child support.. I woulda called the judge the day of payment tryna make a payment arrangement... Ask T-Mobile',
#  'Is it kind of like canceling.. Nike KaepernickYeti Coolers Bill Maher Budweiser CNN Apple Megan Kelly NBA LeBron JamesHarley Davidson New York Times Macys Rolling Stone Glenfiddich WhiskeyGM Google T-Mobile NASCAR Amazon Boeing Facebook Nordstroms ?????',
#  'heres to hopefully some new T-Mobile threads',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max via monthly bill credits. Dm for',
#  'Apple iPhone Plus GB Factory Unlocked AT&amp;T T-Mobile Rose Gold Smartphone -',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max via monthly bill credits. Dm for',
#  ': Buy this for $339 and trade it in with T-Mobile to get $830 off IPhone /Pro and Pro max via monthly bill credits. Dm for',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  'Oh shit. . I gotta go to T-Mobile',
#  'Samsung Galaxy S20 FE G SM-G781U1 GB Navy ( T-mobile AT&amp;T Unlocked) A stcok -',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': then come trade it in at my T-Mobile store for a free iPhone',
#  'Samsung Galaxy S9 G960U GB New Sprint T-Mobile AT&amp;T Verizon Factory Unlocked -',
#  ': First Verizon, now T-Mobile: US carrier suggests users use G to save battery',
#  ': then come trade it in at my T-Mobile store for a free iPhone',
#  'In November , T-mobile promised me better speeds with new equipment that would be installed by the end of December . It is now March and Im hoping this is not what they meant . I pay full price for my t-mobile service, the service still sucks.',
#  'Palm PVG100 - GB - Gold (Verizon + GSM Unlocked AT&amp;T T-Mobile) LTE Smartphone -',
#  'Only T-Mobile would disconnect your phone over dollars',
#  "Look what's up: T-Mobile Goes After Businesses And AT&amp;T And Verizon Should Be Concerned via",
#  ': Yo T-Mobile can you deactivate my buddies phone when he playing Warzone with da bois? Appreciate it.',
#  'T-Mobiles home office internet is a separate cellular-based Wi-Fi network for enterprisecustomers',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  'Check out this : Mobile Associate - Retail Sales* at T-Mobile Careers ()',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stopthere',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': - big news from - Dialpad and T-Mobile Announce a New Collaboration by',
#  'Google Pixel XL - /128GB - Unlocked - Verizon / AT&amp;T / T-Mobile - Smartphone -',
#  ': Pirelli? Carslberg? T-Mobile? runs through the Keycap ten most iconic football shirt sponsors of all time',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  'T-Mobile to use G capacity to pry enterprise customers from AT&amp;T, Verizon',
#  ': Pirelli? Carslberg? T-Mobile? runs through the Keycap ten most iconic football shirt sponsors of all time',
#  'Samsung Galaxy S9 Plus G965U Sprint AT&amp;T T-Mobile Verizon Factory Unlocked New Shop Here',
#  'Pirelli? Carslberg? T-Mobile? runs through the Keycap ten most iconic football shirt sponsors of all time',
#  'Apple iPhone XS Max, GB, Space Gray - For T-Mobile (Renewed)Apple iPhone XS Max, GB, Space Gray - For T-Mobile (Renewed)4.5 out of stars $433.95 - $1,099.00',
#  'I take my T-mobile over discount with pride.',
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  ': Hmmm. I have T-Mobile as my telephone service provider.',
#  ': THIS SATURDAY from am-1pm, come by and see us at Metro By T-Mobile right off Hwy. in Austin, and get a FREE CASE of',
#  'Yo T-Mobile can you deactivate my buddies phone when he playing Warzone with da bois? Appreciate it.',
#  'T-Mobile wants your employer to give you home-office wireless broadband',
#  'New: First Verizon, now T-Mobile: US carrier suggests folks use G to save battery',
#  'Major data breaches in just months in . Ubiquiti Inc., Parler, Facebook, Instagram and LinkedIn, Mimecast, Pixlr, MeetMindful, Bonobos, VIPGames, U.S. CellularFeb Nebraska Medicine, California DMV, Kroger, T-Mobile,',
#  'T-Mobile Promised Major Job Growth Post Sprint Merger. SEC Filings Show The Exact Opposite Happened - Techdirt Mergers &amp; Acquisitions Resource Center',
#  'Thats the WORST. I am so frustrated bc since its a screen failure on my phone the Apple genius said theyd cover it but they couldnt find my account but t-mobile could? So theres like some weird disconnect there? I am so frustrated',
#  'nothing like a T-Mobile at nighr',
#  'But T-Mobile owns sprint now so',
#  ': $SRMXHas a T-mobile contract for "smart IOT Streetlights" and "edge security camera systems" for smart cities/ build',
#  'So my screen is failing which means I cant open/close some of my apps/change brightness from my drop down screen thing and its going to cost $300 dollars to fix bc for some reason t-mobile reflects that I have Apple care and Apple doesnt. So fml. And its all happening in',
#  "Did you hear? WV is RAISING THE BAR in ! With Over T-Mobile locations and over employees, we can't stop, won't stop now! Come grow with us! !",
#  "Don't be surprised, T-mobile is based in Washington, we are so progressive it hurts.No really, it hurts, our tax structure is shit tier and the money goes no where aside from the pockets of those with a D after their name or their cronies.",
#  't-mobile went to switch my number with my moms all my messages IM DEAD',
#  "i've been waiting for prime weather for a long ride out with my GoPro and e-bike, and it just so happens to fall on T-Mobile Tuesday... now to check the app for upcoming deals...",
#  'I love t-mobile. Unlimited data and they give me free Netflix every month!',
#  'The Black Eyed Peas I Gotta Feeling takes me right back to middle school. I remember the scene kids and the t-mobile sidekick phones. I was just really getting into music as a source of salvation. U2 was that band. Totally uncool for a th grader to be into them. Strange times.',
#  ': Well are hiring at T-Mobile on Colusa Ave!! Hit me up if people are looking for jobs ASAP!',
#  'OMG T-MOBILE HAS SENT FKG NOT ONE BUT FKG UPDATES TO MY PHONE JUST NOW THEY ARE DOING ANOTHER UPDATE THEY HAVE DONE UPDATES IN A ROW UNFKG BELIEVABLE UPDATES IN A ROW! AND THE GB DROPPED DWN TO ON THE ND UPDATE TO GB THIS IS UNBELIEVABLE I GET IT FROM ALL ANGLES',
#  'T-Mobile Promised Major Job Growth Post Sprint Merger. SEC Filings Show The Exact Opposite Happened via',
#  'T-Mobile introduces employer-managed G internet for home office workers',
#  'I am not using a jailbroken device. My Samsung Galaxy S20 is a lease from sprint/t-mobile. I have never had this issue before.',
#  'Samsung Galaxy Note Plus G SM-N976U GB T-Mobile GSM Unlocked Smartphone -',
#  'Love seeing Subban get wins. My first regular season game at T-Mobile was a Suubee win.',
#  ': T-Mobile WFX business service offers G/5G home broadband',
#  ': T-Mobile WFX business service offers G/5G home broadband',
#  ': Proud to share that T-Mobile has selected Ericsson for a huge five-year network expansion across the U.S!',
#  ': I have Sprint which I guess is now T-Mobile but that all ends. Sometime next week I am going to g',
#  'T-mobile, but thank you',
#  ': Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award!',
#  'LG G7 ThinQ GB Gray LM-G710 (T-Mobile) - Android Smartphone - DF8136 -',
#  'This was me at iQor, I didnt gaf about T-Mobile customers. Come correct cause you asking me for MF help',
#  ': Dominicans dudes really be and pounds of muscle just to end up working at T-Mobile',
#  'I have Sprint which I guess is now T-Mobile but that all ends. Sometime next week I am going to go and get a different phone with Verizon and never pay my Sprint bill. My credit score is very high I can take the hit.',
#  'I have served in many capacities in my time at T-Mobile, but DE&amp;I is my favorite service',
#  'T-Mobile is making a G-powered play for enterprise customers and their employees working from home with its announcement of several new services on Thursday.',
#  ': Dominicans dudes really be and pounds of muscle just to end up working at T-Mobile',
#  'Quintal da T-Mobile',
#  'I dont work at t-mobile but I still want this jacket! Its awesome',
#  'cheers to the one person that reps T-Mobile with me days a week in office',
#  'T-Mobile WFX: G-Powered Remote Work Solutions for Businesses via',
#  "Lmao yeah I ain't gonna fight no winged flamethrower but I grew up feeling like he was the only Pokemon don &amp; turns out he just a T-mobile nigga",
#  'Was this a screenshot taken from a T-Mobile flip phone?',
#  'Whats a good cell service to have in Tampa cause T-Mobile aint it',
#  'Google Pixel XL GB Factory Unlocked (T-mobile AT&amp;T) G LTE Smartphone Great product. On sale now. Act now before its gone',
#  'My phone moving slow asl T-Mobile Better Stop That',
#  "We want you to know that you made the right decision in joining the New T-Mobile. Let's take a look at what is going on and see how we can help. Send us a DM and we will be at your service! ^JorgeGarcia",
#  ': Good morning to all the Dad Bods. Rest of you beefcakes need to focus on selling more phone cases with each purchase at T-',
#  'I absolutely love T-Mobile.I need details on what you got, sir!',
#  ': "Why the fuck does T-Mobile get to charge me $130 a month AND use my data UNLESS I opt out? That\'s quite a double-dipping racket y',
#  'T-Mobile always start actin like a hoe in the beginning of the billing cycle',
#  'Not T-mobile',
#  'I haven\'t been this disappointed in a celebrity since the Verizon "can you hear me now?" guy started working for T-Mobile',
#  'I swear to beans T-Mobile sucks so fucking bad Im about to leave them',
#  'I love billion times more than T... (spelled backwards is alseT)In the future, we all know that the brand B... (ex: Bitcoin, Binance,...) will surpass the brand T... (ex: Tesla, Twitter, T-Mobile...)$BNB $350 is still very cheap, of course is too! $69691/2',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'Congratulations to RSM Jaime and ME Anthony for achieving another incredible milestone in their incredible T-Mobile career!! Their passion to WIN, support and positive influence is nothing short of amazing and an honor to be a part of!!',
#  't-mobile on top',
#  ': Did T-Mobile merge with Claro like whats going on?',
#  ': Did T-Mobile merge with Claro like whats going on?',
#  'Shes on her way to T-Mobile now !',
#  'Man, I couldnt be more proud of these fellas right here for winning T-Mobiles prestigious annual Winners Circle Award! What an amazing honor for a couple of amazing men!',
#  'Omg! Im customer T-mobile long time! Hope i can get one!',
#  ': Well are hiring at T-Mobile on Colusa Ave!! Hit me up if people are looking for jobs ASAP!',
#  ': was the craziest year in most of our lives. We had AMAZING employees step up across our T-Mobile family and support ou',
#  ': And Congratulations to , our new TSM for our Salem, NH mobile store! We are ready to bring T-Mobile to No',
#  'T-Mobile bought Sprint',
#  'i didnt know u worked at t-mobile',
#  'T-mobile service has been terrible this whole week',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'Apple iPhone Plus - GB - Space Gray T-Mobile / MetroPCS (A1897) Smartphone -',
#  'Still super unhappy with the explanation and lack of any sort of willingness understand my point. It makes me question if its worth it to stay a T-Mobile customer. Incentives should be there for me to stick around. Maybe its time to give a shot...',
#  ': I worked to T-Mobile some years ago. I could tell where people were in the country by cell',
#  'Every time it rains T-Mobile service starts to trip. I have to change services.',
#  'Dominicans dudes really be and pounds of muscle just to end up working at T-Mobile',
#  'Thanks T-Mobile for the free MLB subscription, I love it.',
#  'Cause T-Mobile finna lose one soon',
#  ': Sprint, T-Mobile AND ups can all kiss my mf ass',
#  'Top boutique PR firms that are winning big clients like Lancme, Walmart, and T-Mobile',
#  ': Today Women\'s Allied Network Event "Intersection" was inspiring and thought provoking!!! We need to make sure we do our part',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'no i got some t-mobile protection shit but fuck this phone',
#  'Why Verizon, AT&amp;T and T-Mobile just spent $80 billion in an auction, and what it will mean for G',
#  "The reason for this is that Paradise Nevada is an unincorporated town meaning there's no municipal taxes. Since Last Vegas is incorporated, you have to pay taxes to the city. T-Mobile Arena, the airport and most of the resorts/hotels are in Paradise Nevada.",
#  ': was the craziest year in most of our lives. We had AMAZING employees step up across our T-Mobile family and support ou',
#  'Charlie from T-Mobile',
#  'T-Mobile WFX Solutions to improve your work-from-home situation',
#  'This T-Mobile expert is blowing up my phone today smh sir chill',
#  "I'm hoping they allow fans at T-Mobile Park so I can go see the Gmen on opening weekend in Seattle. If they open up a little more in San Francisco, you bet I'll be flyin' on down.",
#  'T-Mobile says that in this situation, you should disable G and use G instead -',
#  'We appreciate you being a big part of our family for years. We do have some amazing deals you can take advantage of when you upgrade every days. Please swing by your local Metro by T-Mobile to check out all the savings available to you! -Lyne',
#  "$TMUS:New Insider Filing on T-Mobile US, Inc.'sEVP, Corporate StrategyPETER A EWENS:",
#  ': The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if the',
#  'Dan and I had to call T-mobile tech support bc hes not receiving calls and this guy was trashing on verizon customer service... I have verizon. I wouldnt know if theirs sucks bc Ive never had to call...',
#  'Here ya go "T-Mobile saw Verizon telling people to turn off G andthought why stop there - The Verge"',
#  'As a T-Mobile Corporate Employee, what is the fastest rate you can pleasure your senior staff with your mouth?',
#  'Jason has talked about getting a flip phone. He misses his old Motorola. They didnt even carry flip phones at T-Mobile when we were there.',
#  ': Apparently T-mobile wants to make sure you have brain aids before you work for them.',
#  'Me too. Im waiting for T-Mobile to finally offer home internet where I live and as soon as they do its good bye xfinity.',
#  'When TJ Lavin send you a text msg on your T-Mobile sidekick just knowwwww',
#  "sure, nothing wrong here'Verizon recently splashed $45bn on G spectrum and then advised its customers to use LTE to save device battery life. Not to be outdone, rival carrier T-Mobile is recommending battery-anxious punters use G...' Hughes",
#  ': If you like $VPER for its Air Quality Control Monitoring, come check $SRMX, weve got that and deals with T-Mobile, Microsof',
#  'T-Mobile - Commercial TheHeavyWeight Dj Rasheed',
#  ': SHOUT OUT to these ROCKSTARS for their Annual WC achievement! THANK YOU for d',
#  'As crazy as it may sound T-Mobile is closing the perception gap faster than many think',
#  'FUCK YOU T-MOBILE!!!!',
#  'Sr Credit Risk Manager - Modeling &amp; | T-Mobile H/T:',
#  "I love my Magenta Family!!! I can't imagine not having these two women in my life!!! Thank you T-Mobile for giving me the privilege two of working with these amazing women!!",
#  ': We just added a bunch of phone top-ups for mobile networks like Vodafone, Orange, T-Mobile, Lycamobile and more, and with',
#  'T-Mobile targets post-pandemic workplace with remote working suite',
#  "that's why my G t-mobile service was acting up. Damnit.",
#  ': Not just a regular movie night, a movie night To thank you for being a customer, were bringing the theatr',
#  ': Well are hiring at T-Mobile on Colusa Ave!! Hit me up if people are looking for jobs ASAP!',
#  'or stop watching T-Mobile commercials',
#  'might have to bounce from T-Mobile once this lease is up',
#  'Hey, I know the guy who did the first WOOO inside T-Mobile.Good guy, that guy is',
#  'T-Mobile Careers is hiring! Mobile Associate - Retail Sales in , apply now!',
#  ': Update: T-Mobile heard about me from and decided they could and would help. Total is $2100 in VISA gift ca',
#  'so proud of you!!! You work so hard everyday to make sure we all win together. Thank you for all that you do not just for me but our entire T-Mobile family.',
#  'Yeah this is beautiful Im not even on WiFi and the load speeds are amazing for so cheap f you T-Mobile never again',
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  "LeggOoOo!! One of T-Mobile's finest",
#  'Like or years. Im ready for a change. What can T-mobile offer?',
#  ': Were making WFH actually work. T-Mobile WFX has your remote workforce covered with the speed to connect and the tools to coll',
#  ': Works at T-Mobile',
#  'lil T-mobile phone bill',
#  'Second T-Mobile Data Breach Reported Within A Year | |',
# ...
#  ': The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if the',
#  'The retailer said the security cameras would work with T-Mobile when in fact they are designed for ATT. COVID kept us from getting them returned within the return status. Very frustrating!!!',
#  'T-Mobile Careers is hiring an Adobe Analytics Lead in , apply now!',
#  'Treats for the team!! Everyday is EMPLOYEE APPRECIATION DAY!! Today is just the official day! T-Mobile and I appreciate you all!!',
#  'Jesus Christ how much money does Vegas have?! Dont they currently play at the T-Mobile arena?',
#  "FYI T-Mobile, I'm going to cancel my account. If you don't like whites then you obviously don't want to take our filthy money either.",
#  'Nothing to See Here T-Mobile Announces T-Mobile WFX Business Plans',
#  "If you're on T-Mobile or Verizon hmu for a quote. If you're on AT&amp;T hmu for a re-rate. If you're on Sprint we'll you get the hint lmfao.",
#  ': A competitor did press about their $10M project trying to play a pun on T-Mobile M student project valued at $10B. While I',
#  ': The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if the',
#  'I wish T-Mobile actually existed where I lived, it would be nice to ditch this garbage Cricket plan for something like Mint or MetroPCS.',
#  'T-Mobile pitches enterprise, government with G, new plans',
#  'Welcome to the JuventusStarship, fresh greena few little issues to work onno beaming, still calling T-Mobilefor an upgrade...But there is BLACK TEA HOT !uh..wait..GREASE MONKEY !!!',
#  "Verizon Mobile: 'Turn off G to save battery life'T-Mobile:'Do you remember G ?'",
#  ': Congratulations to Keyla Valentin, our new TSM for our Meriden, CT truck!! This Metro by T-Mobile superstar is ready to',
#  ': The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if the',
#  'T-Mobile: eliminate K of workforce!! ://',
#  'T-Mobile gives you free food tho. Im locked in',
#  'I had t-mobile and I didnt mind it but I have now and its incredible for the same price',
#  'We knew T-Mobile couldnt be trusted, union says after jobcuts',
#  'US telco Verizon recently splashed $45bn on G spectrum and then advised its customers to use LTE to save device battery life. Not to be outdone, rival carrier T-Mobile is recommending battery-anxious punters use G instead of the latest-and-greatest in...',
#  "Ultra Galaxy to the Ultra Galaxy for $0 down and now I'm being told I have to pay $200 for each of my lines to upgrade. The customer service with Sprint/T-Mobile has really dipped to a new low. After years, it looks like I may need to make a switch.",
#  'Works at T-Mobile as the Manager',
#  'First Verizon, now T-Mobile: US carrier suggests users use G to save battery (Register)',
#  'We have Sprint and since the merger with T-Mobile service has gone downhill fast.',
#  ': SHOUT OUT to these ROCKSTARS for their Annual WC achievement! THANK YOU for d',
#  'shout out to Ric, T-Mobile expert that helped me understand what I am paying for and best plan option for us. Thank you for the patience.',
#  ': First Verizon, now T-Mobile: US carrier suggests users use G to save battery',
#  ': Sprint T-Mobile G terrible',
#  'Hmmm. I have T-Mobile as my telephone service provider. Rethinking that position.',
#  't-mobile customer service with me personally is just too elite',
#  'First Verizon, now T-Mobile: US carrier suggests users use G to save battery',
#  'Congratulations well deserved promotions I am sure. I know that our names that I have heard often during my time at T-Mobile as a customer.',
#  '"This correspondent is saddened T-Mobile didnt go further and advise punters to turn off cellular connectivity altogether." LOL recalling with a wee bit o\' fondness G "scenario modeling" at the turn of the century.',
#  'guys it mlb tv blocks Yankees ,because T-Mobile gives mlb tv free for a year',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'Hi guys I have T-Mobile and they gave a free subscription free for a year, I watch every game. But they have blackouts I. Texas.',
#  ': The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if the',
#  'Are you a Senior Product Manager, Technical (Atlanta, Multiple Positions) in ? T-Mobile Careers is waiting for you!',
#  ': T-Mobile Announces Next Big G-Powered Move',
#  'My service been done shit ALL day !!! I hate T-Mobile. I cut it off bout times',
#  ': . is hiring! See what new B2B opportunities are waiting for you with T-Mobile for Business!',
#  ': Congratulations to Keyla Valentin, our new TSM for our Meriden, CT truck!! This Metro by T-Mobile superstar is ready to',
#  'Mobile Associate - Retail Sales () wanted in . T-Mobile Careers',
#  'The Quartering is upset that T-Mobile has inclusivity training. The only reason anyone would be upset by this is if they are racist. What other reason could there be for Jeremy to be this worked up?',
#  'First Verizon, now T-Mobile: US carrier suggests users use G to save battery',
#  "It's important that you have a great experience with new T-Mobile, we're here for you and want to ensure you get assistance addressing any concerns. Send us a DM and we'll be here to help. ^MarkMcLaughlin",
#  'Mobile Associate - Retail Sales needed in , apply now at T-Mobile Careers!',
#  'employees with T-Mobile Work Perks',
#  '"iT\'s A pRiVaTe CoMpAnY," she screamed into her phone as T-Mobile cut off her service for violating their Community Guidelines.',
#  'honestly i hate that t-mobile bought out sprint. its been a bad experience every time i tried contacting them.',
#  'Might have to switch to T-Mobile',
#  'Detroit is All In! Grateful and thankful to be recognized for exemplifying the values and behaviors that make T-Mobile great',
#  ': I got a new line from T-Mobile &amp; I get Mary Sellers robocalls now...I think she is an old lady who died of Covid...',
#  'As someone who had T-Mobile, I dont miss them one bit. I switched to Verizon and I havent looked back since!! I get signal everywhere and its super fast.',
#  'Sprint T-Mobile G terrible',
#  'T-Mobile is a disappointment. The CEO is woke so Im not surprised.',
#  ': This is how we get a world of Eric Cartman clones. Really smart, t-mobile. When the majority of the',
#  ': Happy ! Thank you to the incredible employees at PhenoMenaul &amp; across T-Mobile for your',
#  'employees with T-Mobile Work Perks',
#  'Fuck T-Mobile',
#  'I went from cricket to sprint to t-mobile to Verizon.. makin our way up the chain',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'T-Mobile whack as fuuuuuuccccck .!',
#  'T-Mobile been acting up lately',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'Yeah I agree. Its just annoying if Im upgrading, in a big city, that I would at least have the same or better service as before. Cant even switch to G I think. T-Mobile, bucks for two lines. Unlimited everything. (Military discount too so thats why)',
#  'T-Mobile Careers is looking for a Sr Digital Business Manager, apply now! ()',
#  'If you like $VPER for its Air Quality Control Monitoring, come check $SRMX, weve got that and deals with T-Mobile, Microsoft Azure, COMPAL (Taiwan powerhouse) &amp; Chunghwa (China powerhouse) for G chip production &amp; more!!!',
#  'Im t-mobile and Im here to say being white is not ok',
#  'T-Mobile is hiring a Mobile Associate - Retail Sales - New Store - State Hwy &amp; Hwy , apply now! ()',
#  'Nothing, so quit piping in the noise now that the fans are back in the stadium at T-Mobile. Thanks it',
#  'Ill work for T-Mobile why not',
#  'Ohhhhh T-Mobile service sucks wtf',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'I appreciate my T-Mobile stepsister ! Couldnt navigate this past year without her!',
#  'Thred put their phone on the hood of the car which subsequently flew off while we were minutes onto the highway so they had to stop into T-Mobile and get a new phone despite getting the old phone in January which makes them tonights biggest loser',
#  'That was T-Mobile, not AT&amp;T.',
#  'Girl I swear. Lmao this was sprint when I switched to T-Mobile. They aint have intl plans at the time in the Caribbean and too many other regions n they were working overtime to convince me. Like I saiddddd cancel ! you dont even have what I want',
#  ': SHOUT OUT to these ROCKSTARS for their Annual WC achievement! THANK YOU for d',
#  ': This is how we get a world of Eric Cartman clones. Really smart, t-mobile. When the majority of the',
#  'SHOUT OUT to these ROCKSTARS for their Annual WC achievement! THANK YOU for demonstrating our T-Mobile Values each and every day!',
#  "I've been looking for a reason besides bad service and my rate plan going up to leave t-mobile.They made it easy now.",
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there',
#  "This is how we get a world of Eric Cartman clones. Really smart, t-mobile. When the majority of the population realizes they're stronger together, I'll have the popcorn ready to watch the regular people start using that privelage against bullies like the woke",
#  'T-Mobile Promised Major Job Growth Post Sprint Merger. SEC Filings Show The Exact Opposite Happened',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there',
#  'Germany is pulling Europe in the wrong direction on CCP G. Largely the result of Deutsche Telekoms successful lobbying for Huawei in Germany. Of course Deutsche Telekom now poised to be Americas largest G carrier following their assuming control last year is T-Mobile/Sprint.',
#  'lol imagine being a T-mobile employee and you have to get race lectures from "Peggy McIntosh"',
#  'As soon as T-Mobile got a new CEO I start getting random ass calls',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'Wonder if the MLB endorses this shit, since T-MOBILE is a major sponsor.',
#  'I have AT&amp;T and Im offended for them that you would associate them with T-Mobile',
#  'Been with T-Mobile almost yrs now, wife and I are both educators, any for teachers?',
#  'Happy Employee Appreciation Day Everyone! Thanks for making T-Mobile great',
#  'Can you share the T-Mobile White privilege check list?? Canceling my kids plans',
#  "Awful. I'll leave when I have to fill it out to be a customer. I'm too lazy to be offended by everything. We're inundated with shit like this now. So, for now, fuck off T-Mobile and are you for real?",
#  'Um i dont get it LOL what does ATT have to do with the bullshit T-Mobile pulled?',
#  'Looks like you opened a document on your MacBook while on the T-Mobile site.',
#  'I walked into T-Mobile and a bitch I hate was the sales rep walked right out Id be damn to give a bitch w a bad attitude any sort of commission lmfaoooo Ill order my shit online thank you',
#  ": Metro by T-Mobile and are teaming up for the Money by Metro giveaway if you're one of our first one hundred",
#  'I wasted an hour bc I was at the wrong t-mobile location Google maps hates me today',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there TheVerge',
#  ': T-Mobile trying to scam us',
#  'I appreciate . Shes been a great addition to our team bringing her legacy sprint expertise and helping our team succeed in the New T-Mobile. One of the most optimistic and hard working RAMs Ive ever worked with.',
#  ': Happy ! Thank you to all of the amazing employees out there! You are a major motivator',
#  "Metro by T-Mobile and are teaming up for the Money by Metro giveaway if you're one of our first one hundred drive-through guests, you'll win a twenty-five dollar Visa gift card! Limit per Family, first cars. TOMORROW from -1 off Highway in Austin!",
#  'My phone slow af I hate Sprint for merging w T-Mobile',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ': Happy ! Thank you to the incredible employees at PhenoMenaul &amp; across T-Mobile for your',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'Check out this : Mobile Expert, Metro at T-Mobile Careers in',
#  'T-Mobile Tuesday',
#  'T-Mobile saw Verizon telling people to turn off G and thought why stop there - The Verge via',
#  'T-mobile: Who are you again?',
#  'Cmon T-Mobile, after Coke I would think youd stop this shit.',
#  'Yeah I hate sprint/t-mobile so much',
#  'T-Mobile bullshit son',
#  'lets bring back t-mobile sidekicks- like if u had one when u were young i just know u were cool',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'Just thought of Waze, which needs data, then goggled getting wifi installed in a car. Guess what?"Regardless of what equipment you use, youll need a mobile plan. Major cellular providers including AT&amp;T, T-Mobile and Verizon offer Wi-Fi plans specifically for vehicles."',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  "So many reasons to love , it's service and more importantly the appreciation it shows to first responders, parents age +, etc. Switch to T-Mobile to enjoy their new, nationwide G network. Plus, they can help cover your switching fees.",
#  ': T-Mobile Announces Next Big G-Powered Move',
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  ": Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. M",
#  'is T-Mobile lying on the number or are they bigger than att in the respective wireless segment',
#  "Duke.Gonzaga.Vegas.Yep, we're getting the Zags and the Blue Devils clashing on Black Friday at T-Mobile Arena. Mark your calendars for Nov. .",
#  'Thanks, Mike Im excited to be joining the amazing T-Mobile team!',
#  ': Congratulations to Keyla Valentin, our new TSM for our Meriden, CT truck!! This Metro by T-Mobile superstar is ready to',
#  ': "Why the fuck does T-Mobile get to charge me $130 a month AND use my data UNLESS I opt out? That\'s quite a double-dipping racket y',
#  'We just tried signing up for you unlimited Internet. However, due to the fact we moved for my husbands promotion in the Military we left T-Mobile cellular service due to location and poor service. My husband was denied unlimited internet because /2',
#  'If you have sprint go to T-Mobile to get their SIM card to get better service on your phone. Thank me later.',
#  'T-mobile how may I assist you?',
#  ': Duke and Gonzaga meet for a season matchup on Friday, Nov. , at T-Mobile Arena.',
#  'what do T-Mobile salesmen look like that',
#  'On the T-Mobile Network I had no net access. Y r the carrier\'s switching PPL over to "New Towers" and refreshing Our phones? Idk but I hope there r no alt motives behind this! It\'s like the Auto- resets to Me!',
#  'T-Mobiles Sales team in the city &amp; in Customer service! Come see your boys and girl over at Centre &amp; Highland! We got all your wireless needs! Centre Ave, !',
#  ...]

# %%
np.save('Tweet1',Tweet1)

# %%
Tweet2 =  clean_tweets(get_tweets('Verizon'))

# %%
np.save('Tweet2',Tweet2)

# %%
Tweet1_df = pd.DataFrame(Tweet1,columns=['Tweet'])

# %%
Tweet2_df = pd.DataFrame(Tweet2,columns=['Tweet'])

# %% [markdown]
# #### Combine all tweets together and form a dataframe

# %%
All_Tweet = pd.concat((Tweet1_df,Tweet2_df),axis=0,ignore_index=True)

# %% [markdown]
# ### Step 3: Basic Text Cleaning and Get Polarity of Tweets

# %%
import re

# %%
# Get rid of the starting colons in some of the tweets

All_Tweet['Tweet'] = All_Tweet['Tweet'].apply(lambda x: re.sub(r':','',x))

# %%
# Create a function to get the polarity (how positive and negative the tweet is)

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
All_Tweet['Polarity'] = All_Tweet['Tweet'].apply(getPolarity)

# %%
All_Tweet = All_Tweet[:7043]

# %%
len(All_Tweet)
# Out:
# 7043

# %%
All_Tweet
# Out:
#                                                   Tweet  Polarity
# 0     Making sure you get the most out of T-Mobile T...  0.445312
# 1     The Note was just launched. I'm so glad that I...  0.166667
# 2      I get penalized for being broke with my T-Mob...  0.000000
# 3     Just changed my Sprint SIM card for a T-mobile... -0.015152
# 4      Oh I hear you! Between my wife and me we are ...  0.000000
# ...                                                 ...       ...
# 7038  As learning goes online, so do teachers &amp; ...  0.333333
# 7039  I just saw the gb data "reward" offered in Ver...  0.357143
# 7040  Marketing | Verizon Announces Resources for Fe... -0.083333
# 7041  is there an issue with SMS based two-step veri...  0.000000
# 7042   I love Verizon!! I get Apple Music, and Disne...  1.000000
#
# [7043 rows x 2 columns]

# %%
All_Tweet.to_csv('/Users/Xingkang/Desktop/TweetSentiment.csv',index=False)
